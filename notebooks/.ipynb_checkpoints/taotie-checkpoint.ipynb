# %%
import pandas as pd # Option/Alt + Enter

# %%
# %pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      -------------------------------------- 60.9/60.9 kB 641.2 kB/s eta 0:00:00
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.6 MB 2.2 MB/s eta 0:00:06
#    ---------------------------------------- 0.1/11.6 MB 2.2 MB/s eta 0:00:06
#    ---------------------------------------- 0.1/11.6 MB 2.2 MB/s eta 0:00:06
#    ---------------------------------------- 0.1/11.6 MB 655.4 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.6 MB 655.4 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.6 MB 655.4 kB/s eta 0:00:18
# ...

# %%
df = pd.read_parquet(r'E:\07-taotie-7-7-describe-rewrite\assets\sample.parquet')

# %%
# %pip install pandas pyarrow
# Out:
# ...
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/25.1 MB 825.8 kB/s eta 0:00:31
#    ---------------------------------------- 0.2/25.1 MB 1.7 MB/s eta 0:00:15
#     --------------------------------------- 0.3/25.1 MB 2.2 MB/s eta 0:00:12
#     --------------------------------------- 0.6/25.1 MB 2.7 MB/s eta 0:00:10
#    - -------------------------------------- 0.8/25.1 MB 3.3 MB/s eta 0:00:08
#    - -------------------------------------- 1.1/25.1 MB 3.9 MB/s eta 0:00:07
#    -- ------------------------------------- 1.4/25.1 MB 4.2 MB/s eta 0:00:06
#    -- ------------------------------------- 1.8/25.1 MB 4.9 MB/s eta 0:00:05
# Note: you may need to restart the kernel to use updated packages.
#    --- ------------------------------------ 2.2/25.1 MB 5.4 MB/s eta 0:00:05
# ...

# %%
df
# Out:
#                                  email  \
# 0       b'rickie.6cl60vv5@example.net'
# 1         b'olaf.14ymhjtf@example.org'
# 2      b'rebecca.3a623w6u@example.com'
# 3       b'yvonne.qx06kzs6@example.org'
# 4       b'juston.apls64ti@example.org'
# ..                                 ...
# 995        b'una.inxgk1lq@example.com'
# 996  b'raphaelle.kk6ikbeq@example.net'
# 997   b'josianne.ceoqsbol@example.org'
# 998     b'anabel.r5dxwncd@example.com'
# 999   b'patricia.eft3oxwx@example.org'
#
#                                         name      gender  \
# 0    b'\xe5\xbd\xad\xe6\x9d\xb0\xe8\xa3\x95'  b'unknown'
# 1    b'\xe9\xad\x8f\xe7\x92\x87\xe7\x9b\x88'  b'unknown'
# 2    b'\xe7\x86\x8a\xe7\x95\x85\xe7\x91\x9e'  b'unknown'
# 3    b'\xe5\xad\x9f\xe7\x91\x9c\xe6\x98\x95'  b'unknown'
# 4    b'\xe9\x92\xb1\xe6\x9d\x89\xe6\x99\x96'  b'unknown'
# ..                                       ...         ...
# 995  b'\xe5\x94\x90\xe4\xba\x91\xe7\x87\x95'  b'unknown'
# ...

# %%
df.head()
# Out:
#                              email                                     name  \
# 0   b'rickie.6cl60vv5@example.net'  b'\xe5\xbd\xad\xe6\x9d\xb0\xe8\xa3\x95'
# 1     b'olaf.14ymhjtf@example.org'  b'\xe9\xad\x8f\xe7\x92\x87\xe7\x9b\x88'
# 2  b'rebecca.3a623w6u@example.com'  b'\xe7\x86\x8a\xe7\x95\x85\xe7\x91\x9e'
# 3   b'yvonne.qx06kzs6@example.org'  b'\xe5\xad\x9f\xe7\x91\x9c\xe6\x98\x95'
# 4   b'juston.apls64ti@example.org'  b'\xe9\x92\xb1\xe6\x9d\x89\xe6\x99\x96'
#
#        gender                       created_at  \
# 0  b'unknown' 2020-08-10 13:01:25.925310+00:00
# 1  b'unknown' 2021-11-13 13:00:25.903489+00:00
# 2  b'unknown' 2020-03-27 01:20:25.909394+00:00
# 3  b'unknown' 2022-07-04 00:23:25.871170+00:00
# 4  b'unknown' 2023-11-15 00:40:25.923932+00:00
#
#                    last_visited_at                  last_watched_at  \
# 0 2024-05-04 09:50:25.925310+00:00 2024-04-16 14:54:25.925310+00:00
# 1 2024-04-25 20:57:25.903489+00:00 2024-02-14 23:31:25.903489+00:00
# ...

# %%
df.describe()
# Out:
#                                    email  \
# count                               1000
# unique                              1000
# top     b'patricia.eft3oxwx@example.org'
# freq                                   1
# mean                                 NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
#
#                                            name      gender  \
# count                                      1000        1000
# unique                                      986           1
# top     b'\xe7\x94\xb0\xe9\xb8\xbf\xe6\x89\xbf'  b'unknown'
# freq                                          2        1000
# mean                                        NaN         NaN
# min                                         NaN         NaN
# 25%                                         NaN         NaN
# ...

# %%
df[df['created_at'] >= '2024-01-25'] # select * from df where created_at >= '2024-01-25'
# Out:
#                                   email  \
# 12   b'candelario.k09qbm2w@example.net'
# 26       b'meghan.zfz2xq8m@example.org'
# 240    b'theresia.qffrdky6@example.net'
# 491      b'gaston.ar4k3eld@example.org'
# 630       b'vesta.ogpio1y5@example.org'
# 712   b'broderick.nw0o1x33@example.net'
#
#                                         name      gender  \
# 12   b'\xe5\x91\xa8\xe9\xb8\xbf\xe6\x89\xbf'  b'unknown'
# 26   b'\xe5\x94\x90\xe7\x80\x9a\xe5\x90\x9b'  b'unknown'
# 240  b'\xe5\xb4\x94\xe5\xbd\xac\xe9\x94\x90'  b'unknown'
# 491  b'\xe6\x9b\xbe\xe5\x93\xb2\xe5\x8d\x97'  b'unknown'
# 630  b'\xe4\xbb\x98\xe9\xbe\x99\xe5\xbe\xb7'  b'unknown'
# 712  b'\xe8\x92\x8b\xe9\xbb\x9b\xe4\xba\xa6'  b'unknown'
#
#                           created_at                  last_visited_at  \
# 12  2024-01-29 03:30:25.926680+00:00 2024-04-12 22:26:25.926680+00:00
# 26  2024-01-31 07:49:25.897247+00:00 2024-04-14 09:03:25.897247+00:00
# ...

# %%
df[df['created_at'] >= '2024-01-25'].count()
# Out:
# email                       6
# name                        6
# gender                      6
# created_at                  6
# last_visited_at             6
# last_watched_at             6
# recent_watched              6
# viewed_but_not_started      6
# started_but_not_finished    6
# finished                    6
# last_email_notification     6
# last_in_app_notification    6
# last_sms_notification       6
# dtype: int64
